# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashSalmuthe/Python-Noteboks/blob/main/Pie_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import style

# %%
classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]

# %%
plt.pie([1])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f2865f690>],
#  [Text(-1.1, 1.3471114790620887e-16, '')])

# %%
plt.pie(class1_students)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f282d9550>,
# ...
#  [Text(0.5947049149539254, 0.9253788759906099, ''),
#   Text(-0.7371546940193954, 0.8164575660039973, ''),
#   Text(-1.0815121854958625, -0.2008267726772585, ''),
#   Text(-0.178723762423877, -1.0853837186659168, ''),
#   Text(0.9003515932576855, -0.6319549101940323, '')])

# %%
plt.pie(class1_students,labels=classes)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27d65b90>,
# ...
#  [Text(0.5947049149539254, 0.9253788759906099, 'Python'),
#   Text(-0.7371546940193954, 0.8164575660039973, 'R'),
#   Text(-1.0815121854958625, -0.2008267726772585, 'Macine Learning'),
#   Text(-0.178723762423877, -1.0853837186659168, 'Artificial Intelligence'),
#   Text(0.9003515932576855, -0.6319549101940323, 'Data Science')])

# %%
classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0,0,0,0,0]

plt.pie(class1_students,labels=classes)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27cc9350>,
# ...
#  [Text(0.5947049149539254, 0.9253788759906099, 'Python'),
#   Text(-0.7371546940193954, 0.8164575660039973, 'R'),
#   Text(-1.0815121854958625, -0.2008267726772585, 'Macine Learning'),
#   Text(-0.178723762423877, -1.0853837186659168, 'Artificial Intelligence'),
#   Text(0.9003515932576855, -0.6319549101940323, 'Data Science')])

# %%
# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0,0,0.2,0,0]

plt.pie(class1_students,labels=classes,explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27c0d050>,
# ...
#  [Text(0.5947049149539254, 0.9253788759906099, 'Python'),
#   Text(-0.7371546940193954, 0.8164575660039973, 'R'),
#   Text(-1.2781507646769283, -0.23734073134585099, 'Macine Learning'),
#   Text(-0.178723762423877, -1.0853837186659168, 'Artificial Intelligence'),
#   Text(0.9003515932576855, -0.6319549101940323, 'Data Science')])

# %%
# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0.3,0,0.2,0,0]

plt.pie(class1_students,labels=classes,explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27b69050>,
# ...
#  [Text(0.7568971644868141, 1.177754933078958, 'Python'),
#   Text(-0.7371546940193954, 0.8164575660039973, 'R'),
#   Text(-1.2781507646769283, -0.23734073134585099, 'Macine Learning'),
#   Text(-0.178723762423877, -1.0853837186659168, 'Artificial Intelligence'),
#   Text(0.9003515932576855, -0.6319549101940323, 'Data Science')])

# %%
# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0.05,0,0.1,0,0]
colors = ['c','b','r','y','g']

plt.pie(class1_students,labels=classes,explode=explode,colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27a6f9d0>,
# ...
#  [Text(0.6217369565427402, 0.9674415521720012, 'Python'),
#   Text(-0.7371546940193954, 0.8164575660039973, 'R'),
#   Text(-1.1798314750863954, -0.21908375201155475, 'Macine Learning'),
#   Text(-0.178723762423877, -1.0853837186659168, 'Artificial Intelligence'),
#   Text(0.9003515932576855, -0.6319549101940323, 'Data Science')])

# %%
plt.figure(figsize=(13,7))

# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0.05,0,0.1,0,0]
colors = ['c','b','r','y','g']

plt.pie(class1_students,labels=classes,explode=explode,colors=colors,autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27834d50>,
# ...
#  [Text(0.6217369565427402, 0.9674415521720012, 'Python'),
#   Text(-0.7371546940193954, 0.8164575660039973, 'R'),
#   Text(-1.1798314750863954, -0.21908375201155475, 'Macine Learning'),
#   Text(-0.178723762423877, -1.0853837186659168, 'Artificial Intelligence'),
#   Text(0.9003515932576855, -0.6319549101940323, 'Data Science')],
#  [Text(0.3514165406545922, 0.5468147903580877, '31.8%'),
#   Text(-0.4020843785560338, 0.44534049054763486, '9.7%'),
#   Text(-0.6882350271337305, -0.1277988553400736, '22.7%'),
#   Text(-0.09748568859484198, -0.5920274829086818, '16.2%'),
#   Text(0.4911008690496466, -0.34470267828765394, '19.5%')])

# %%
plt.figure(figsize=(13,7))

# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0.05,0,0.1,0,0]
colors = ['c','b','r','y','g']

plt.pie(class1_students,labels=classes,explode=explode,colors=colors,autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27825190>,
# ...
#  [Text(0.6217369565427402, 0.9674415521720012, 'Python'),
#   Text(-0.7371546940193954, 0.8164575660039973, 'R'),
#   Text(-1.1798314750863954, -0.21908375201155475, 'Macine Learning'),
#   Text(-0.178723762423877, -1.0853837186659168, 'Artificial Intelligence'),
#   Text(0.9003515932576855, -0.6319549101940323, 'Data Science')],
#  [Text(0.3514165406545922, 0.5468147903580877, '31.82%'),
#   Text(-0.4020843785560338, 0.44534049054763486, '9.74%'),
#   Text(-0.6882350271337305, -0.1277988553400736, '22.73%'),
#   Text(-0.09748568859484198, -0.5920274829086818, '16.23%'),
#   Text(0.4911008690496466, -0.34470267828765394, '19.48%')])

# %%
plt.figure(figsize=(13,7))

# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0.05,0,0.1,0,0]
colors = ['c','b','r','y','g']

plt.pie(class1_students,labels=classes,explode=explode,colors=colors,autopct='%0.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27ce3810>,
# ...
#  [Text(0.6217369565427402, 0.9674415521720012, 'Python'),
#   Text(-0.7371546940193954, 0.8164575660039973, 'R'),
#   Text(-1.1798314750863954, -0.21908375201155475, 'Macine Learning'),
#   Text(-0.178723762423877, -1.0853837186659168, 'Artificial Intelligence'),
#   Text(0.9003515932576855, -0.6319549101940323, 'Data Science')],
#  [Text(0.3514165406545922, 0.5468147903580877, '31.82%'),
#   Text(-0.4020843785560338, 0.44534049054763486, '9.74%'),
#   Text(-0.6882350271337305, -0.1277988553400736, '22.73%'),
#   Text(-0.09748568859484198, -0.5920274829086818, '16.23%'),
#   Text(0.4911008690496466, -0.34470267828765394, '19.48%')])

# %%
plt.figure(figsize=(13,7))

# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0.05,0,0.1,0,0]
colors = ['c','b','r','y','g']

plt.pie(class1_students,labels=classes,explode=explode,colors=colors,autopct='%0.2f%%',shadow=True,radius=1.4)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f278f4f50>,
# ...
#  [Text(0.8596189225243103, 1.3375931025682453, 'Python'),
#   Text(-1.0320165716271534, 1.1430405924055962, 'R'),
#   Text(-1.6124363492847402, -0.2994144610824581, 'Macine Learning'),
#   Text(-0.25021326739342775, -1.5195372061322832, 'Artificial Intelligence'),
#   Text(1.2604922305607598, -0.8847368742716452, 'Data Science')],
#  [Text(0.48117034028090316, 0.7487156360287661, '31.82%'),
#   Text(-0.5629181299784474, 0.6234766867666889, '9.74%'),
#   Text(-0.9242013221510096, -0.17161560574238455, '22.73%'),
#   Text(-0.13647996403277876, -0.8288384760721544, '16.23%'),
#   Text(0.6875412166695053, -0.4825837496027155, '19.48%')])

# %%
plt.figure(figsize=(13,7))

# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0.05,0,0.1,0,0]
colors = ['c','b','r','y','g']

plt.pie(class1_students,labels=classes,explode=explode,colors=colors,autopct='%0.2f%%',shadow=True,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27ac7a10>,
# ...
#  [Text(-0.9674415521720012, 0.6217369565427402, 'Python'),
#   Text(-0.8164575660039973, -0.7371546940193954, 'R'),
#   Text(0.21908375201155467, -1.1798314750863954, 'Macine Learning'),
#   Text(1.0853837186659168, -0.17872376242387705, 'Artificial Intelligence'),
#   Text(0.6319549101940323, 0.9003515932576854, 'Data Science')],
#  [Text(-0.5468147903580877, 0.3514165406545922, '31.82%'),
#   Text(-0.44534049054763486, -0.4020843785560338, '9.74%'),
#   Text(0.12779885534007357, -0.6882350271337305, '22.73%'),
#   Text(0.5920274829086818, -0.09748568859484201, '16.23%'),
#   Text(0.34470267828765394, 0.49110086904964656, '19.48%')])

# %%
plt.figure(figsize=(13,7))

# Explode is used for sclice 

classes = ['Python','R','Macine Learning',"Artificial Intelligence","Data Science"]
class1_students = [49,15,35,25,30]
explode=[0.05,0,0.1,0,0]
colors = ['c','b','r','y','g']
textprops = {'fontsize':15}

plt.pie(class1_students,labels=classes,explode=explode,colors=colors,autopct='%0.2f%%',shadow=True,startangle=90,textprops=textprops)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f27aa3fd0>,
# ...
#  [Text(-0.9674415521720012, 0.6217369565427402, 'Python'),
#   Text(-0.8164575660039973, -0.7371546940193954, 'R'),
#   Text(0.21908375201155467, -1.1798314750863954, 'Macine Learning'),
#   Text(1.0853837186659168, -0.17872376242387705, 'Artificial Intelligence'),
#   Text(0.6319549101940323, 0.9003515932576854, 'Data Science')],
#  [Text(-0.5468147903580877, 0.3514165406545922, '31.82%'),
#   Text(-0.44534049054763486, -0.4020843785560338, '9.74%'),
#   Text(0.12779885534007357, -0.6882350271337305, '22.73%'),
#   Text(0.5920274829086818, -0.09748568859484201, '16.23%'),
#   Text(0.34470267828765394, 0.49110086904964656, '19.48%')])
